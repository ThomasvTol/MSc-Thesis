# %% [markdown]
# # STEP 2 Analysis and visualisation Base ensemble extra kpis (with no covid)
# * Visualiation of the model split of various trip purposes

# %% [markdown]
# ## Load results

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from ema_workbench.analysis.plotting import lines, Density,kde_over_time, envelopes, multiple_densities



#load results
from ema_workbench import ema_logging, load_results


results = load_results(r'./results/2709_policy_run_base_v6_1000_trip_purp.tar.gz')


experiments, outcomes = results

# %% [markdown]
# # Modal split per trip purpose

# %% [markdown]
# ### modal split bike

# %%
#Modal splt commutign bike 
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split bike per motive[commuting]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_bike_commute')

#modal split educational bike
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split bike per motive[educational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_bike_edu')

#modal split recreational bike
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split bike per motive[recreational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_bike_socrec')

#modal split shop bike
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split bike per motive[shopping personal care]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_bike_shop')

#modal split other bike
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split bike per motive[other motive]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_bike_other')

# %% [markdown]
# ### modal split car

# %%
#modal split car commute 
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split car per motive[commuting]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_car_commute')

#modal split educational car
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split car per motive[educational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_car_edu')

#modal split recreational car
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split car per motive[recreational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_car_socrec')

#modal split shop car
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split car per motive[shopping personal care]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_car_shop')

#modal split other car
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split car per motive[other motive]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_car_other')

# %% [markdown]
# ### modal split PT

# %%
#modal split Pt commute 
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split public transport per motive[commuting]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
    
ax[0].set(xlim=(2019,2030))
ax[0].set(ylim=(0.09,0.1))
sns.despine()
plt.savefig('figs/new/plcy_split_pt_commute')

#modal split educational PT
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split public transport per motive[educational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_pt_edu')

#modal split recreational pt
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split public transport per motive[recreational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
    
ax[0].set(xlim=(2019,2030))
ax[0].set(ylim=(0.04,0.05)) 
sns.despine()
plt.savefig('figs/new/plcy_split_pt_socrec')

#modal split shop pt
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split public transport per motive[shopping personal care]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_pt_shop')

#modal split other pt
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split public transport per motive[other motive]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_pt_other')

# %% [markdown]
# ### modal split tele

# %%
#modal split tele commute 
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split tele per motive[commuting]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_tele_commute')

#modal split educational tele
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split tele per motive[educational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_tele_edu')

#modal split recreational tele
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split tele per motive[recreational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_tele_socrec')

#modal split shop tele
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split tele per motive[shopping personal care]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_tele_shop')

#modal split other tele
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split tele per motive[other motive]', group_by = 'policy',density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_tele_other')
# Out:
# singular matrix
# singular matrix
# singular matrix
# singular matrix
# singular matrix
# singular matrix

# %% [markdown]
# ### modal split walk

# %%
#modal split walk commute 
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split walk per motive[commuting]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_walk_commute')

#modal split educational walk
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split walk per motive[educational]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_walk_edu')

#modal split recreational walk
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split walk per motive[recreational]',group_by = 'policy',density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_walk_socrec')

#modal split shop walk
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split walk per motive[shopping personal care]',group_by = 'policy', density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_walk_shop')

#modal split other walk
fig, _ = lines(experiments, outcomes,outcomes_to_show = 'Modal split walk per motive[other motive]', group_by = 'policy',density =Density.KDE, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

#ax[0].set_ylabel('Modal split')
for line in ax[0].get_lines():
    line.set_alpha(0.05)
    line.set_linewidth(0.5)
sns.despine()
plt.savefig('figs/new/plcy_split_walk_other')
