# %% [markdown]
# # STEP 3 Analysis and visualisation of the uncertainties
# * Global and COVID uncertainties

# %% [markdown]
# ## Load results
# * from the 1000 or 5000 run experiment

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from ema_workbench.analysis.plotting import lines, Density,kde_over_time, envelopes, multiple_densities



#load results
from ema_workbench import ema_logging, load_results
#results = load_results(r"./results/1308_1000_runs_all_v2.tar.gz")
results = load_results(r"./prim_results/1508_5000_runs_correct_prim.tar.gz")


experiments, outcomes = results

# %%
#pt trips
fig, _ = lines(experiments, outcomes, outcomes_to_show = "Total Public Transport movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#tele trips
fig, _ = lines(experiments, outcomes, outcomes_to_show = "Total Telecommuting movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#tele trips
fig, _ = lines(experiments, outcomes, outcomes_to_show = "Total Modal split telecommuting" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %% [markdown]
# ## Visualisation of Total modal split

# %%
#pt trips
fig, _ = lines(experiments, outcomes, outcomes_to_show = "Total Public Transport movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#tele trips
fig, _ = lines(experiments, outcomes, outcomes_to_show = "Total Telecommuting movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()
