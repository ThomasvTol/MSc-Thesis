# %% [markdown]
# # STEP 4: explore uncertainties with PRIM

# %% [markdown]
# ## Scenario exploration: PRIM

# %%
from ema_workbench.analysis.plotting import lines, Density,kde_over_time, envelopes, multiple_densities
from ema_workbench import ema_logging, load_results, Scenario
from ema_workbench.analysis import prim, dimensional_stacking

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import matplotlib as mpl
import numpy as np



ema_logging.log_to_stderr(ema_logging.INFO)



file_name = r"./prim_results/1508_5000_runs_correct_prim.tar.gz"
results = load_results(file_name)
# Out:
# [MainProcess/INFO] results loaded successfully from C:\Users\thomas\Documents\MSc TIL\Afstuderen\EMAWB\thesis project\prim_results\1508_5000_runs_correct_prim.tar.gz

# %% [markdown]
# # MODAL split

# %%
def classify(data):
    #get the output for modal split PT
    PTsplit = data['Total Modal split PT']
    return PTsplit[:, -1] > 0.06

# %%
# has to be done for each selected model outcome 
prim_obj = prim.setup_prim(results, classify, threshold=0.8, threshold_type=1)
box_1 = prim_obj.find_box()
box_1.show_ppt()
box_1.show_tradeoff()

box_1.inspect(style="graph", boxlim_formatter="{: .2f}")
box_1.inspect()
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category
# [MainProcess/INFO] 5000 points remaining, containing 3543 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.3962, coverage: 0.5591306802145075, density: 1.0 restricted_dimensions: 3
# coverage     0.559131
# density      1.000000
# id          18.000000
# mass         0.396200
# mean         1.000000
# res_dim      3.000000
# Name: 18, dtype: float64
#
#                                                       box 18            \
#                                                          min       max
# Expected telecommuting                              0.120038  0.272044
# Perception public transport rate of gaining bac...  0.253471  0.599948
# Variable Car cost increase                          0.015018  0.099984
#
#
#                                                                          qp values
# Expected telecommuting                               [-1.0, 6.150175394883748e-99]
# Perception public transport rate of gaining bac...  [4.720966844990527e-111, -1.0]
# Variable Car cost increase                          [2.7493835429449363e-14, -1.0]

# %% [markdown]
# # Congestion < 116

# %%
def classify(data):
    #get the output for modal split PT
    congestionclass = data['Congestion level']
    return congestionclass [:, -1] < 1160000

# %%
prim_obj = prim.setup_prim(results, classify, threshold=0.8, threshold_type=1)
box_1 = prim_obj.find_box()
box_1.show_ppt()
box_1.show_tradeoff()

box_1.inspect(style="graph", boxlim_formatter="{: .2f}")
box_1.inspect()
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category
# [MainProcess/INFO] 5000 points remaining, containing 2943 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.2622, coverage: 0.4454638124362895, density: 1.0 restricted_dimensions: 3
# coverage     0.445464
# density      1.000000
# id          26.000000
# mass         0.262200
# mean         1.000000
# res_dim      3.000000
# Name: 26, dtype: float64
#
#                                                       box 26            \
#                                                          min       max
# Variable Car cost increase                          0.043032  0.099984
# Expected telecommuting                              0.225145  0.349959
# Perception public transport rate of gaining bac...  0.171733  0.599948
#
#
#                                                                          qp values
# Variable Car cost increase                            [1.5094105785409e-138, -1.0]
# Expected telecommuting                              [1.1848042402873789e-77, -1.0]
# Perception public transport rate of gaining bac...  [1.7908552859592797e-07, -1.0]

# %% [markdown]
# # tele

# %%
def classify(data):
    #get the output for modal split PT
    teletrips = data['Total Telecommuting movements per month']
    return teletrips[:, -1] > 52000000

# %%
# has to be done for eeach selecte dmodel outcome 
prim_obj = prim.setup_prim(results, classify, threshold=0.8, threshold_type=1)
box_1 = prim_obj.find_box()
box_1.show_ppt()
box_1.show_tradeoff()

box_1.inspect(style="graph", boxlim_formatter="{: .2f}")
box_1.inspect()
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category
# [MainProcess/INFO] 5000 points remaining, containing 2822 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.4624, coverage: 0.8192771084337349, density: 1.0 restricted_dimensions: 1
# coverage     0.819277
# density      1.000000
# id          15.000000
# mass         0.462400
# mean         1.000000
# res_dim      1.000000
# Name: 15, dtype: float64
#
#                           box 15
#                              min       max    qp values
# Expected telecommuting  0.243641  0.349959  [0.0, -1.0]

# %%
box_2 = prim_obj.find_box()
box_2.show_ppt()
box_2.show_tradeoff()

box_2.inspect(style="graph", boxlim_formatter="{: .2f}")
box_2.inspect()
# Out:
# [MainProcess/INFO] 2688 points remaining, containing 510 cases of interest
# [MainProcess/INFO] mean: 0.9888888888888889, mass: 0.054, coverage: 0.09461374911410347, density: 0.9888888888888889 restricted_dimensions: 2
# coverage     0.094614
# density      0.988889
# id          46.000000
# mass         0.054000
# mean         0.988889
# res_dim      2.000000
# Name: 46, dtype: float64
#
#                               box 46            \
#                                  min       max
# Expected telecommuting      0.221896  0.349959
# Variable Car cost increase  0.039211  0.099984
#
#
#                                                   qp values
# Expected telecommuting      [1.2479099420246834e-154, -1.0]
# Variable Car cost increase    [4.223730137176913e-27, -1.0]

# %% [markdown]
# # modal split car/ tele

# %%
def classify(data):
    #get the output for modal split PT
    splitcar = data['Total Modal split telecommuting']
    return splitcar[:, -1] > 0.035

# %%
# has to be done for eeach selecte dmodel outcome 
prim_obj = prim.setup_prim(results, classify, threshold=0.8, threshold_type=1)
box_1 = prim_obj.find_box()
box_1.show_ppt()
box_1.show_tradeoff()

box_1.inspect(style="graph", boxlim_formatter="{: .2f}")
box_1.inspect()
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category
# [MainProcess/INFO] 5000 points remaining, containing 3537 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.598, coverage: 0.845349165959853, density: 1.0 restricted_dimensions: 1
# coverage     0.845349
# density      1.000000
# id          10.000000
# mass         0.598000
# mean         1.000000
# res_dim      1.000000
# Name: 10, dtype: float64
#
#                           box 10
#                              min       max    qp values
# Expected telecommuting  0.212463  0.349959  [0.0, -1.0]

# %%
box_2 = prim_obj.find_box()
box_2.show_ppt()
box_2.show_tradeoff()

box_2.inspect(style="graph", boxlim_formatter="{: .2f}")
box_2.inspect()
# Out:
# [MainProcess/INFO] 2010 points remaining, containing 547 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.0524, coverage: 0.07407407407407407, density: 1.0 restricted_dimensions: 2
# coverage     0.074074
# density      1.000000
# id          39.000000
# mass         0.052400
# mean         1.000000
# res_dim      2.000000
# Name: 39, dtype: float64
#
#                               box 39
#                                  min       max                       qp values
# Expected telecommuting      0.196028  0.349959  [2.012057738441482e-125, -1.0]
# Variable Car cost increase  0.028055  0.099984  [2.0144166557136391e-16, -1.0]

# %% [markdown]
# ## Test with envelopes
# * not used

# %%
grouping_specifiers_vot={'high scenario': (0.2, 0.25), 
                     'low scenario': (0.15, 0.2)
                     }

# %%
#import matplotlib.pyplot as plt
#from ema_workbench.analysis.plotting import lines, Density, kde_over_time, envelopes, multiple_densities

experiments, outcomes = results

#experiments = results
#envelopes(experiments, 'Total Public Transport movements per month',  
#          group_by= 'Expected telecommuting', grouping_specifiers=grouping_specifiers_vot, titles=False, 
#       legend=True, density =Density.KDE, ylabels=None, fill=True, )
#plt.ylabel('tele movements ')

envelopes(experiments, outcomes, outcomes_to_show=['Total Telecommuting movements per month'],
       group_by= 'Expected telecommuting', grouping_specifiers=grouping_specifiers_vot, titles=False,
          legend=True, density =Density.KDE, ylabels=None, fill=True, )
plt.ylabel('Tele movements ')
# Out:
# Text(0, 0.5, 'Tele movements ')
