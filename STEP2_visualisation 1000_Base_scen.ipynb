# %% [markdown]
# # STEP 2 Analysis and visualisation of the KPIs
# * Base input value

# %% [markdown]
# ## Load results

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from ema_workbench.analysis.plotting import lines, Density,kde_over_time, envelopes, multiple_densities



#load results
from ema_workbench import ema_logging, load_results
results = load_results(r"./results/1308_1000_runs_base_covid_v2.tar.gz")


experiments, outcomes = results

# %% [markdown]
# ## Visualisation of the results

# %%
#Pt trips
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Public Transport movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#tele trips
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Telecommuting movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#car trips
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total car movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#bike trips
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total bicycle movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#walking trips
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total walking movements per month" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#modal split car
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Modal split car" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#modal split PT
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Modal split PT" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#modal split bike
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Modal split Bicycle" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#modal split tele
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Modal split telecommuting" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#modal split walk
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Total Modal split Walking" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#Road intesity short 
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Road intensity[short trips]" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#Road intesity middle short 
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Road intensity[middleshort trips]" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#Road intesity long
fig, _ = lines(experiments, outcomes,outcomes_to_show = "Road intensity[long trips]" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#car trips commute 

fig, _ = lines(experiments, outcomes,outcomes_to_show = "Monthly car movements per motive[commuting]" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()

# %%
#car trip educational

fig, _ = lines(experiments, outcomes,outcomes_to_show = "Monthly car movements per motive[educational]" , density =Density.KDE,  titles=False, ylabels=None)

fig.set_size_inches(10,5)
ax = fig.get_axes()

for line in ax[0].get_lines():
    line.set_alpha(0.1)
    line.set_linewidth(0.7)
sns.despine()
